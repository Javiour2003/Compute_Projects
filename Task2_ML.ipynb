# %%
import pandas as pd
import numpy as np
import seaborn as sns
df = pd.read_csv("/content/Compute_ML_Task.csv")
df.head()
# Out:
#    Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 0             1000025                5                        1
# 1             1002945                5                        4
# 2             1015425                3                        1
# 3             1016277                6                        8
# 4             1017023                4                        1
#
#    Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                         1                  1                            2
# 1                         4                  5                            7
# 2                         1                  1                            2
# 3                         8                  1                            3
# 4                         1                  3                            2
#
#    Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses  Class
# ...

# %%
df.shape
# Out:
# (683, 11)

# %%
df.describe()
# Out:
#        Sample code number  Clump Thickness  Uniformity of Cell Size  \
# count        6.830000e+02       683.000000               683.000000
# mean         1.076720e+06         4.442167                 3.150805
# std          6.206440e+05         2.820761                 3.065145
# min          6.337500e+04         1.000000                 1.000000
# 25%          8.776170e+05         2.000000                 1.000000
# 50%          1.171795e+06         4.000000                 1.000000
# 75%          1.238705e+06         6.000000                 5.000000
# max          1.345435e+07        10.000000                10.000000
#
#        Uniformity of Cell Shape  Marginal Adhesion  \
# count                683.000000         683.000000
# mean                   3.215227           2.830161
# std                    2.988581           2.864562
# min                    1.000000           1.000000
# 25%                    1.000000           1.000000
# ...

# %%
df.nunique()
# Out:
# Sample code number             630
# Clump Thickness                 10
# Uniformity of Cell Size         10
# Uniformity of Cell Shape        10
# Marginal Adhesion               10
# Single Epithelial Cell Size     10
# Bare Nuclei                     10
# Bland Chromatin                 10
# Normal Nucleoli                 10
# Mitoses                          9
# Class                            2
# dtype: int64

# %%
df['Mitoses'].unique()
# Out:
# array([ 1,  5,  4,  2,  3,  7, 10,  8,  6])

# %%
#Cleaning the data

# %%
df.isnull().sum()
# Out:
# Sample code number             0
# Clump Thickness                0
# Uniformity of Cell Size        0
# Uniformity of Cell Shape       0
# Marginal Adhesion              0
# Single Epithelial Cell Size    0
# Bare Nuclei                    0
# Bland Chromatin                0
# Normal Nucleoli                0
# Mitoses                        0
# Class                          0
# dtype: int64

# %%
cell = df.drop(['Sample code number'],axis=1)
cell.head()
# Out:
#    Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# 0                5                        1                         1
# 1                5                        4                         4
# 2                3                        1                         1
# 3                6                        8                         8
# 4                4                        1                         1
#
#    Marginal Adhesion  Single Epithelial Cell Size  Bare Nuclei  \
# 0                  1                            2            1
# 1                  5                            7           10
# 2                  1                            2            2
# 3                  1                            3            4
# 4                  3                            2            1
#
#    Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 0                3                1        1      2
# 1                3                2        1      2
# ...

# %%
cell.describe()
# Out:
#        Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# count       683.000000               683.000000                683.000000
# mean          4.442167                 3.150805                  3.215227
# std           2.820761                 3.065145                  2.988581
# min           1.000000                 1.000000                  1.000000
# 25%           2.000000                 1.000000                  1.000000
# 50%           4.000000                 1.000000                  1.000000
# 75%           6.000000                 5.000000                  5.000000
# max          10.000000                10.000000                 10.000000
#
#        Marginal Adhesion  Single Epithelial Cell Size  Bare Nuclei  \
# count         683.000000                   683.000000   683.000000
# mean            2.830161                     3.234261     3.544656
# std             2.864562                     2.223085     3.643857
# ...

# %%
#Relationship Analysis

# %%
sns.pairplot(cell)

# %%
sns.relplot(y='Uniformity of Cell Size',x='Uniformity of Cell Shape',hue='Class',data=cell,kind='line')

# %%
#The uniformity of cell shape increases with uniformity of cell size across both the classes.

# %%
sns.relplot(x='Single Epithelial Cell Size',y='Marginal Adhesion',data=cell,hue='Class',kind='line')

# %%
#Logistic Regression

# %%
cell.rename(columns={'Uniformity of Cell Size' : 'UoCSize'},inplace=True)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(cell[['Clump Thickness','UoCSize','Uniformity of Cell Shape','Marginal Adhesion','Single Epithelial Cell Size','Bare Nuclei',	'Bland Chromatin',	'Normal Nucleoli',	'Mitoses']],cell.Class,train_size=0.8,random_state=10)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_predicted = model.predict(X_test)
y_predicted
# Out:
# array([4, 4, 4, 4, 4, 4, 2, 2, 4, 4, 4, 2, 2, 2, 4, 2, 2, 4, 2, 4, 2, 2,
#        2, 2, 4, 2, 2, 2, 2, 2, 2, 4, 4, 4, 2, 4, 4, 4, 2, 2, 4, 2, 4, 2,
#        4, 2, 4, 2, 2, 2, 2, 2, 2, 2, 2, 2, 4, 4, 2, 4, 2, 4, 2, 4, 2, 2,
#        2, 2, 2, 2, 2, 2, 4, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 4, 4, 2, 2,
#        2, 2, 4, 2, 2, 2, 2, 2, 2, 2, 2, 2, 4, 2, 4, 4, 2, 2, 2, 2, 4, 2,
#        4, 2, 2, 4, 2, 2, 4, 2, 2, 2, 2, 4, 2, 4, 4, 4, 4, 2, 4, 2, 2, 2,
#        2, 2, 4, 4, 4])

# %%
print(np.array(X_test))
# Out:
# [[10 10 10 ...  4 10 10]
#  [ 3  3  5 ...  7  1  1]
#  [10  2  2 ...  1  1  2]
#  ...
#  [ 7  6 10 ...  9 10  2]
#  [10  8  8 ...  8  1  1]
#  [ 7  6  3 ...  7  4  6]]

# %%
model.score(X_test, y_test)
# Out:
# 0.9708029197080292

# %%
#This model shows the accuracy of prediction of Uniformity of Cell Size(Considered as Dependent variable) with respect to Uniformity of Cell Shape(considered as independent variable).
#The accuracy is 97.080% .

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
confusion_matrix(y_test,y_predicted)
# Out:
# array([[87,  2],
#        [ 2, 46]])

# %%
cfm=confusion_matrix(y_test,y_predicted)
sns.heatmap(cfm,annot=True)

# %%
accuracy_score(y_test, y_predicted)
# Out:
# 0.9708029197080292
